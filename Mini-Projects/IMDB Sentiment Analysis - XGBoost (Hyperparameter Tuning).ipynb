# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# 'five minutes after watching this i logged on to IMDb to warn all of you out there not to bother with this movie... genre:horror? it had moments of mild suspense and throughout the whole movie i was thinking to myself "somethings gotta happen soon" it did not...when the movie ended i felt so embarrassed for the writer/director i\'ve never been the biggest fan of patrick rea this guy just does not know how to make movies and after watching this sorry excuse of a horror flick i\'ve gone from not been the biggest fan to will not watch another of his works..<br /><br />i was taken in by the plot summary please don\'t make the same mistake.<br /><br />i gave this movie a 2 for the actors..they were not bad and it wasn\'t there fault they got such bad direction...'

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Read features from cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

test_y = pd.DataFrame(test_y)
test_X = pd.DataFrame(test_X)

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
test_X.to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

# %%
test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

test_X.to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating a hypertuned XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. As in the Boston Housing notebook, the first step is to create an estimator object which will be used as the *base* of your hyperparameter tuning job.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator(container, # The image name of the training container
                                    role,      # The IAM role to use (our current role in this case)
                                    train_instance_count=1, # The number of instances to use for training
                                    train_instance_type='ml.m4.xlarge', # The type of instance to use for training
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                        # Where to save the output (the model artifacts)
                                    sagemaker_session=session) # The current SageMaker session

# %%
# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.

xgb.set_hyperparameters(max_depth=6,
                        eta=0.2,
                        gamma=0,
                        min_child_weight=1,
                        subsample=0.8,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)

# %% [markdown]
# ### (TODO) Create the hyperparameter tuner
#
# Now that the base estimator has been set up we need to construct a hyperparameter tuner object which we will use to request SageMaker construct a hyperparameter tuning job.
#
# **Note:** Training a single sentiment analysis XGBoost model takes longer than training a Boston Housing XGBoost model so if you don't want the hyperparameter tuning job to take too long, make sure to not set the total number of models (jobs) too high.

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-05-02 16:09:53 Starting - Starting the training job...
# 2020-05-02 16:09:54 Starting - Launching requested ML instances...
# 2020-05-02 16:10:51 Starting - Preparing the instances for training.........
# 2020-05-02 16:12:17 Downloading - Downloading input data
# 2020-05-02 16:12:17 Training - Downloading the training image...
# 2020-05-02 16:12:35 Training - Training image download completed. Training in progress.Arguments: train
# [2020-05-02:16:12:36:INFO] Running standalone xgboost training.
# [2020-05-02:16:12:36:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8472.64mb
# [2020-05-02:16:12:36:INFO] Determined delimiter of CSV input is ','
# [16:12:36] S3DistributionType set as FullyReplicated
# [16:12:38] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-05-02:16:12:38:INFO] Determined delimiter of CSV input is ','
# [16:12:38] S3DistributionType set as FullyReplicated
# [16:12:39] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [16:12:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-error:0.274733#011validation-error:0.288
# Multiple eval metrics have been passed: 'validation-error' will be used for early stopping.
#
# Will train until validation-error hasn't improved in 10 rounds.
# [16:12:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-error:0.269#011validation-error:0.2841
# [16:12:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-error:0.2554#011validation-error:0.2724
# [16:12:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-error:0.2566#011validation-error:0.2754
# [16:12:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-error:0.233#011validation-error:0.2554
# [16:12:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-error:0.229133#011validation-error:0.2551
# [16:12:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-error:0.223467#011validation-error:0.2525
# [16:12:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-error:0.217133#011validation-error:0.2435
# [16:12:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-error:0.212333#011validation-error:0.2381
# [16:12:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-error:0.2078#011validation-error:0.2343
# [16:12:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-error:0.203133#011validation-error:0.2284
# [16:13:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-error:0.197733#011validation-error:0.2245
# [16:13:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-error:0.192733#011validation-error:0.2234
# [16:13:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-error:0.187867#011validation-error:0.2195
# [16:13:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-error:0.179467#011validation-error:0.2154
# [16:13:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-error:0.1762#011validation-error:0.2098
# [16:13:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-error:0.173467#011validation-error:0.2099
# [16:13:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-error:0.17#011validation-error:0.2089
# [16:13:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-error:0.1672#011validation-error:0.2055
# [16:13:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-error:0.164067#011validation-error:0.2015
# [16:13:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-error:0.1604#011validation-error:0.199
# [16:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-error:0.158133#011validation-error:0.199
# [16:13:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-error:0.155467#011validation-error:0.1963
# [16:13:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-error:0.151467#011validation-error:0.1964
# [16:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-error:0.149933#011validation-error:0.1942
# [16:13:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [25]#011train-error:0.1488#011validation-error:0.1938
# [16:13:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [26]#011train-error:0.145867#011validation-error:0.192
# [16:13:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [27]#011train-error:0.144#011validation-error:0.1927
# [16:13:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [28]#011train-error:0.143267#011validation-error:0.1918
# [16:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [29]#011train-error:0.139933#011validation-error:0.1899
# [16:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [30]#011train-error:0.137333#011validation-error:0.1876
# [16:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [31]#011train-error:0.133733#011validation-error:0.1865
# [16:13:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [32]#011train-error:0.131867#011validation-error:0.1856
# [16:13:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [33]#011train-error:0.128867#011validation-error:0.183
# [16:13:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [34]#011train-error:0.127733#011validation-error:0.183
# [16:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [35]#011train-error:0.126133#011validation-error:0.181
# [16:13:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [36]#011train-error:0.125333#011validation-error:0.1796
# [16:13:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [37]#011train-error:0.124867#011validation-error:0.1801
# [16:13:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [38]#011train-error:0.122467#011validation-error:0.1771
# [16:13:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [39]#011train-error:0.1208#011validation-error:0.1772
# [16:13:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [40]#011train-error:0.120267#011validation-error:0.1764
# [16:13:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [41]#011train-error:0.120067#011validation-error:0.1737
# [16:13:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [42]#011train-error:0.118067#011validation-error:0.1737
# [16:13:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [43]#011train-error:0.115667#011validation-error:0.1723
# [16:13:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [44]#011train-error:0.114533#011validation-error:0.1716
# [16:13:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [45]#011train-error:0.1144#011validation-error:0.1714
# [16:13:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [46]#011train-error:0.1132#011validation-error:0.171
# [16:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [47]#011train-error:0.111333#011validation-error:0.1703
# [16:13:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [48]#011train-error:0.1104#011validation-error:0.17
# [16:13:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [49]#011train-error:0.108133#011validation-error:0.1686
# [16:13:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [50]#011train-error:0.106933#011validation-error:0.1687
# [16:14:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [51]#011train-error:0.105467#011validation-error:0.1684
# [16:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [52]#011train-error:0.104#011validation-error:0.1676
# [16:14:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [53]#011train-error:0.103733#011validation-error:0.1667
# [16:14:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [54]#011train-error:0.1018#011validation-error:0.1654
# [16:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [55]#011train-error:0.101067#011validation-error:0.166
# [16:14:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [56]#011train-error:0.1002#011validation-error:0.1643
# [16:14:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [57]#011train-error:0.098933#011validation-error:0.1627
# [16:14:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [58]#011train-error:0.0982#011validation-error:0.1623
# [16:14:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [59]#011train-error:0.0972#011validation-error:0.1624
# [16:14:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [60]#011train-error:0.095533#011validation-error:0.1623
# [16:14:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [61]#011train-error:0.0946#011validation-error:0.1612
# [16:14:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [62]#011train-error:0.093#011validation-error:0.1605
# [16:14:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [63]#011train-error:0.091067#011validation-error:0.16
# [16:14:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [64]#011train-error:0.090133#011validation-error:0.1596
# [16:14:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [65]#011train-error:0.089867#011validation-error:0.1592
# [16:14:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [66]#011train-error:0.089067#011validation-error:0.1583
# [16:14:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [67]#011train-error:0.087133#011validation-error:0.1583
# [16:14:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [68]#011train-error:0.086533#011validation-error:0.1565
# [16:14:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [69]#011train-error:0.085867#011validation-error:0.1565
# [16:14:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [70]#011train-error:0.085267#011validation-error:0.156
# [16:14:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [71]#011train-error:0.0848#011validation-error:0.1552
# [16:14:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [72]#011train-error:0.084467#011validation-error:0.1546
# [16:14:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [73]#011train-error:0.083933#011validation-error:0.1548
# [16:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [74]#011train-error:0.083#011validation-error:0.154
# [16:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [75]#011train-error:0.083067#011validation-error:0.1532
# [16:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [76]#011train-error:0.082133#011validation-error:0.1532
# [16:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [77]#011train-error:0.0818#011validation-error:0.1536
# [16:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [78]#011train-error:0.081#011validation-error:0.1537
# [16:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [79]#011train-error:0.0802#011validation-error:0.154
# [16:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [80]#011train-error:0.079133#011validation-error:0.154
# [16:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [81]#011train-error:0.077467#011validation-error:0.1526
# [16:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [82]#011train-error:0.076933#011validation-error:0.1521
# [16:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [83]#011train-error:0.075333#011validation-error:0.1516
# [16:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [84]#011train-error:0.074733#011validation-error:0.1504
# [16:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [85]#011train-error:0.074867#011validation-error:0.1496
# [16:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [86]#011train-error:0.0752#011validation-error:0.1499
# [16:14:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [87]#011train-error:0.074667#011validation-error:0.1498
# [16:14:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [88]#011train-error:0.074467#011validation-error:0.1493
# [16:14:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [89]#011train-error:0.0744#011validation-error:0.1493
# [16:14:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [90]#011train-error:0.073867#011validation-error:0.1492
# [16:14:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [91]#011train-error:0.072933#011validation-error:0.1496
# [16:15:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [92]#011train-error:0.072933#011validation-error:0.1494
# [16:15:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [93]#011train-error:0.071933#011validation-error:0.148
# [16:15:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [94]#011train-error:0.070667#011validation-error:0.1476
# [16:15:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [95]#011train-error:0.070533#011validation-error:0.1476
# [16:15:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [96]#011train-error:0.070133#011validation-error:0.1478
# [16:15:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [97]#011train-error:0.0694#011validation-error:0.1466
# [16:15:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [98]#011train-error:0.069467#011validation-error:0.1467
# [16:15:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [99]#011train-error:0.069133#011validation-error:0.1471
# [16:15:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [100]#011train-error:0.068#011validation-error:0.1473
# [16:15:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [101]#011train-error:0.066133#011validation-error:0.1467
# [16:15:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [102]#011train-error:0.065667#011validation-error:0.145
# [16:15:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [103]#011train-error:0.064533#011validation-error:0.1451
# [16:15:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [104]#011train-error:0.063467#011validation-error:0.1453
# [16:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [105]#011train-error:0.0628#011validation-error:0.1446
# [16:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [106]#011train-error:0.0624#011validation-error:0.1441
# [16:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [107]#011train-error:0.062467#011validation-error:0.1455
# [16:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [108]#011train-error:0.0622#011validation-error:0.1458
# [16:15:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [109]#011train-error:0.061933#011validation-error:0.1454
# [16:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [110]#011train-error:0.061933#011validation-error:0.144
# [16:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [111]#011train-error:0.060733#011validation-error:0.1442
# [16:15:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [112]#011train-error:0.060467#011validation-error:0.1437
# [16:15:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [113]#011train-error:0.059933#011validation-error:0.144
# [16:15:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [114]#011train-error:0.0594#011validation-error:0.1442
# [16:15:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [115]#011train-error:0.058733#011validation-error:0.1441
# [16:15:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [116]#011train-error:0.058133#011validation-error:0.1427
# [16:15:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [117]#011train-error:0.057933#011validation-error:0.1431
# [16:15:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [118]#011train-error:0.057933#011validation-error:0.1428
# [16:15:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [119]#011train-error:0.057667#011validation-error:0.1431
# [16:15:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [120]#011train-error:0.057333#011validation-error:0.1431
# [16:15:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [121]#011train-error:0.056667#011validation-error:0.1431
# [16:15:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [122]#011train-error:0.056667#011validation-error:0.1431
# [16:15:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [123]#011train-error:0.0564#011validation-error:0.1431
# [16:15:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [124]#011train-error:0.0566#011validation-error:0.1434
# [16:15:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [125]#011train-error:0.056067#011validation-error:0.1424
# [16:15:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [126]#011train-error:0.0556#011validation-error:0.1431
# [16:15:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [127]#011train-error:0.0554#011validation-error:0.142
# [16:15:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [128]#011train-error:0.054467#011validation-error:0.1417
# [16:15:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [129]#011train-error:0.053933#011validation-error:0.1428
# [16:15:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [130]#011train-error:0.0534#011validation-error:0.1426
# [16:15:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [131]#011train-error:0.0532#011validation-error:0.1419
# [16:16:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [132]#011train-error:0.052867#011validation-error:0.1415
# [16:16:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [133]#011train-error:0.0522#011validation-error:0.1416
# [16:16:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [134]#011train-error:0.052333#011validation-error:0.1417
# [16:16:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [135]#011train-error:0.051267#011validation-error:0.1417
# [16:16:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [136]#011train-error:0.051333#011validation-error:0.1418
# [16:16:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [137]#011train-error:0.0506#011validation-error:0.1416
# [16:16:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [138]#011train-error:0.050267#011validation-error:0.1413
# [16:16:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [139]#011train-error:0.0504#011validation-error:0.1405
# [16:16:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [140]#011train-error:0.049933#011validation-error:0.1409
# [16:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [141]#011train-error:0.0498#011validation-error:0.1409
# [16:16:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [142]#011train-error:0.049733#011validation-error:0.1407
# [16:16:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [143]#011train-error:0.049467#011validation-error:0.1407
# [16:16:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [144]#011train-error:0.049533#011validation-error:0.1415
# [16:16:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [145]#011train-error:0.049133#011validation-error:0.1413
# [16:16:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [146]#011train-error:0.049#011validation-error:0.1417
# [16:16:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [147]#011train-error:0.048867#011validation-error:0.1405
# [16:16:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [148]#011train-error:0.0486#011validation-error:0.1407
# [16:16:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [149]#011train-error:0.047733#011validation-error:0.1402
# [16:16:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [150]#011train-error:0.0474#011validation-error:0.1401
# [16:16:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [151]#011train-error:0.046667#011validation-error:0.1402
# [16:16:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [152]#011train-error:0.0468#011validation-error:0.1398
# [16:16:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [153]#011train-error:0.046467#011validation-error:0.139
# [16:16:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [154]#011train-error:0.0464#011validation-error:0.1386
# [16:16:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [155]#011train-error:0.045733#011validation-error:0.1382
# [16:16:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [156]#011train-error:0.045667#011validation-error:0.1384
# [16:16:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [157]#011train-error:0.045133#011validation-error:0.1376
# [16:16:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [158]#011train-error:0.044533#011validation-error:0.1382
# [16:16:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [159]#011train-error:0.044533#011validation-error:0.1382
# [16:16:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [160]#011train-error:0.044267#011validation-error:0.1372
# [16:16:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [161]#011train-error:0.044333#011validation-error:0.1375
# [16:16:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [162]#011train-error:0.044067#011validation-error:0.1377
# [16:16:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [163]#011train-error:0.043667#011validation-error:0.1376
# [16:16:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [164]#011train-error:0.043467#011validation-error:0.1372
# [16:16:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [165]#011train-error:0.042467#011validation-error:0.137
# [16:16:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [166]#011train-error:0.0424#011validation-error:0.1374
# [16:16:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [167]#011train-error:0.042133#011validation-error:0.1368
# [16:16:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [168]#011train-error:0.041467#011validation-error:0.1362
# [16:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [169]#011train-error:0.041133#011validation-error:0.1354
# [16:16:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [170]#011train-error:0.041#011validation-error:0.1348
# [16:16:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [171]#011train-error:0.041#011validation-error:0.1351
# [16:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [172]#011train-error:0.0412#011validation-error:0.1359
# [16:17:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [173]#011train-error:0.041#011validation-error:0.1359
# [16:17:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [174]#011train-error:0.040733#011validation-error:0.1358
# [16:17:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [175]#011train-error:0.040733#011validation-error:0.1356
# [16:17:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [176]#011train-error:0.0396#011validation-error:0.1352
# [16:17:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [177]#011train-error:0.0394#011validation-error:0.1352
# [16:17:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [178]#011train-error:0.039133#011validation-error:0.1352
# [16:17:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [179]#011train-error:0.038933#011validation-error:0.1354
# [16:17:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [180]#011train-error:0.0388#011validation-error:0.1352
# Stopping. Best iteration:
# [170]#011train-error:0.041#011validation-error:0.1348
#
#
# 2020-05-02 16:17:46 Uploading - Uploading generated training model
# 2020-05-02 16:17:46 Completed - Training job completed
# Training seconds: 351
# Billable seconds: 351

# %%
# First, make sure to import the relevant objects used to construct the tuner
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner

# TODO: Create the hyperparameter tuner object

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb, # The estimator object to use as the basis for the training jobs.
                                               objective_metric_name = 'validation:error', # The metric used to compare trained models.
                                               objective_type = 'Minimize', # Whether we wish to minimize or maximize the metric.
                                               max_jobs = 20, # The total number of models to train
                                               max_parallel_jobs = 3, # The number of models to train in parallel
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 12),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'min_child_weight': IntegerParameter(1, 5),
                                                    'subsample': ContinuousParameter(0.5, 0.9),
                                                    'gamma': ContinuousParameter(0, 10),
                                               })

# %% [markdown]
# ### Fit the hyperparameter tuner
#
# Now that the hyperparameter tuner object has been constructed, it is time to fit the various models and find the best performing model.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')

# %%
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})

# %% [markdown]
# Remember that the tuning job is constructed and run in the background so if we want to see the progress of our training job we need to call the `wait()` method.

# %%
xgb_hyperparameter_tuner.wait()
# Out:
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................!

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've run our hyperparameter tuning job, it's time to see how well the best performing model actually performs. To do this we will use SageMaker's Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# Remember that in order to create a transformer object to perform the batch transform job, we need a trained estimator object. We can do that using the `attach()` method, creating an estimator object which is attached to the best trained job.

# %%
# TODO: Create a new estimator object attached to the best training job found during hyperparameter tuning

xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# 2020-05-02 16:48:25 Starting - Preparing the instances for training
# 2020-05-02 16:48:25 Downloading - Downloading input data
# 2020-05-02 16:48:25 Training - Training image download completed. Training in progress.
# 2020-05-02 16:48:25 Uploading - Uploading generated training model
# 2020-05-02 16:48:25 Completed - Training job completedArguments: train
# [2020-05-02:16:42:24:INFO] Running standalone xgboost training.
# [2020-05-02:16:42:24:INFO] Setting up HPO optimized metric to be : error
# [2020-05-02:16:42:24:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8481.93mb
# [2020-05-02:16:42:24:INFO] Determined delimiter of CSV input is ','
# [16:42:24] S3DistributionType set as FullyReplicated
# [16:42:25] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-05-02:16:42:25:INFO] Determined delimiter of CSV input is ','
# [16:42:25] S3DistributionType set as FullyReplicated
# [16:42:26] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [16:42:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 94 pruned nodes, max_depth=10
# [0]#011train-error:0.247067#011validation-error:0.274
# Multiple eval metrics have been passed: 'validation-error' will be used for early stopping.
#
# Will train until validation-error hasn't improved in 10 rounds.
# [16:42:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 104 pruned nodes, max_depth=10
# [1]#011train-error:0.2394#011validation-error:0.2632
# [16:42:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 78 pruned nodes, max_depth=10
# [2]#011train-error:0.232533#011validation-error:0.2567
# [16:42:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 110 pruned nodes, max_depth=10
# [3]#011train-error:0.224067#011validation-error:0.2493
# [16:42:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 120 pruned nodes, max_depth=10
# [4]#011train-error:0.2178#011validation-error:0.2432
# [16:42:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 102 pruned nodes, max_depth=10
# [5]#011train-error:0.208933#011validation-error:0.2366
# [16:42:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 58 pruned nodes, max_depth=10
# [6]#011train-error:0.200333#011validation-error:0.2293
# [16:42:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 72 pruned nodes, max_depth=10
# [7]#011train-error:0.190067#011validation-error:0.2194
# [16:42:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 92 pruned nodes, max_depth=10
# [8]#011train-error:0.184133#011validation-error:0.2155
# [16:42:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 84 pruned nodes, max_depth=10
# [9]#011train-error:0.1792#011validation-error:0.2097
# [16:42:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 88 pruned nodes, max_depth=10
# [10]#011train-error:0.172133#011validation-error:0.208
# [16:43:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 76 pruned nodes, max_depth=10
# [11]#011train-error:0.167933#011validation-error:0.2035
# [16:43:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 66 pruned nodes, max_depth=10
# [12]#011train-error:0.165067#011validation-error:0.2031
# [16:43:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 86 pruned nodes, max_depth=10
# [13]#011train-error:0.1622#011validation-error:0.2006
# [16:43:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 100 pruned nodes, max_depth=10
# [14]#011train-error:0.159067#011validation-error:0.1981
# [16:43:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 96 pruned nodes, max_depth=10
# [15]#011train-error:0.154933#011validation-error:0.1953
# [16:43:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 82 pruned nodes, max_depth=10
# [16]#011train-error:0.1508#011validation-error:0.193
# [16:43:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 78 pruned nodes, max_depth=10
# [17]#011train-error:0.148067#011validation-error:0.1914
# [16:43:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 52 pruned nodes, max_depth=10
# [18]#011train-error:0.147#011validation-error:0.1885
# [16:43:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 78 pruned nodes, max_depth=10
# [19]#011train-error:0.1434#011validation-error:0.1873
# [16:43:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 70 pruned nodes, max_depth=10
# [20]#011train-error:0.142267#011validation-error:0.1865
# [16:43:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 72 pruned nodes, max_depth=10
# [21]#011train-error:0.1402#011validation-error:0.1842
# [16:43:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 66 pruned nodes, max_depth=10
# [22]#011train-error:0.1376#011validation-error:0.1835
# [16:43:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 54 pruned nodes, max_depth=10
# [23]#011train-error:0.137733#011validation-error:0.1812
# [16:43:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 122 pruned nodes, max_depth=10
# [24]#011train-error:0.1346#011validation-error:0.1786
# [16:43:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 96 pruned nodes, max_depth=10
# [25]#011train-error:0.132067#011validation-error:0.177
# [16:43:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 118 pruned nodes, max_depth=10
# [26]#011train-error:0.129267#011validation-error:0.1738
# [16:43:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 58 pruned nodes, max_depth=10
# [27]#011train-error:0.128467#011validation-error:0.1738
# [16:43:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 66 pruned nodes, max_depth=10
# [28]#011train-error:0.126867#011validation-error:0.1736
# [16:43:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 56 pruned nodes, max_depth=10
# [29]#011train-error:0.125467#011validation-error:0.1717
# [16:43:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 54 pruned nodes, max_depth=10
# [30]#011train-error:0.123133#011validation-error:0.1715
# [16:43:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 82 pruned nodes, max_depth=10
# [31]#011train-error:0.1212#011validation-error:0.1692
# [16:43:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 64 pruned nodes, max_depth=10
# [32]#011train-error:0.1198#011validation-error:0.1689
# [16:43:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 68 pruned nodes, max_depth=10
# [33]#011train-error:0.119067#011validation-error:0.1684
# [16:43:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 66 pruned nodes, max_depth=10
# [34]#011train-error:0.118067#011validation-error:0.1683
# [16:44:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 66 pruned nodes, max_depth=10
# [35]#011train-error:0.117133#011validation-error:0.1674
# [16:44:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 64 pruned nodes, max_depth=10
# [36]#011train-error:0.1158#011validation-error:0.1661
# [16:44:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 62 pruned nodes, max_depth=10
# [37]#011train-error:0.112733#011validation-error:0.1659
# [16:44:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 56 pruned nodes, max_depth=10
# [38]#011train-error:0.113867#011validation-error:0.1653
# [16:44:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 52 pruned nodes, max_depth=10
# [39]#011train-error:0.111867#011validation-error:0.1625
# [16:44:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 62 pruned nodes, max_depth=10
# [40]#011train-error:0.110667#011validation-error:0.1632
# [16:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 94 pruned nodes, max_depth=10
# [41]#011train-error:0.1096#011validation-error:0.163
# [16:44:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 24 pruned nodes, max_depth=10
# [42]#011train-error:0.108733#011validation-error:0.1627
# [16:44:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 136 pruned nodes, max_depth=10
# [43]#011train-error:0.106733#011validation-error:0.1613
# [16:44:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 94 pruned nodes, max_depth=10
# [44]#011train-error:0.1078#011validation-error:0.1615
# [16:44:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 76 pruned nodes, max_depth=10
# [45]#011train-error:0.1066#011validation-error:0.1607
# [16:44:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 96 pruned nodes, max_depth=10
# [46]#011train-error:0.1056#011validation-error:0.1598
# [16:44:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 70 pruned nodes, max_depth=10
# [47]#011train-error:0.1038#011validation-error:0.16
# [16:44:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 86 pruned nodes, max_depth=10
# [48]#011train-error:0.102533#011validation-error:0.16
# [16:44:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 94 pruned nodes, max_depth=10
# [49]#011train-error:0.101333#011validation-error:0.159
# [16:44:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 82 pruned nodes, max_depth=10
# [50]#011train-error:0.101467#011validation-error:0.1584
# [16:44:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 50 pruned nodes, max_depth=10
# [51]#011train-error:0.100267#011validation-error:0.1573
# [16:44:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 68 pruned nodes, max_depth=10
# [52]#011train-error:0.099267#011validation-error:0.1561
# [16:44:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 44 pruned nodes, max_depth=10
# [53]#011train-error:0.0984#011validation-error:0.1552
# [16:44:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 58 pruned nodes, max_depth=10
# [54]#011train-error:0.097867#011validation-error:0.1548
# [16:44:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 64 pruned nodes, max_depth=10
# [55]#011train-error:0.096467#011validation-error:0.154
# [16:44:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 36 pruned nodes, max_depth=10
# [56]#011train-error:0.0956#011validation-error:0.1535
# [16:44:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 72 pruned nodes, max_depth=10
# [57]#011train-error:0.094733#011validation-error:0.154
# [16:45:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 82 pruned nodes, max_depth=10
# [58]#011train-error:0.094#011validation-error:0.1537
# [16:45:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 50 pruned nodes, max_depth=10
# [59]#011train-error:0.093133#011validation-error:0.1529
# [16:45:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 24 pruned nodes, max_depth=10
# [60]#011train-error:0.093#011validation-error:0.1518
# [16:45:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 50 pruned nodes, max_depth=10
# [61]#011train-error:0.0926#011validation-error:0.1518
# [16:45:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 54 pruned nodes, max_depth=10
# [62]#011train-error:0.091467#011validation-error:0.151
# [16:45:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 26 pruned nodes, max_depth=10
# [63]#011train-error:0.091533#011validation-error:0.15
# [16:45:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 48 pruned nodes, max_depth=10
# [64]#011train-error:0.089933#011validation-error:0.1506
# [16:45:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 78 pruned nodes, max_depth=10
# [65]#011train-error:0.090267#011validation-error:0.1507
# [16:45:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 50 pruned nodes, max_depth=10
# [66]#011train-error:0.089533#011validation-error:0.1495
# [16:45:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 42 pruned nodes, max_depth=10
# [67]#011train-error:0.088867#011validation-error:0.1484
# [16:45:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 80 pruned nodes, max_depth=10
# [68]#011train-error:0.0882#011validation-error:0.1491
# [16:45:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 96 pruned nodes, max_depth=10
# [69]#011train-error:0.089067#011validation-error:0.1486
# [16:45:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 86 pruned nodes, max_depth=10
# [70]#011train-error:0.0882#011validation-error:0.1486
# [16:45:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 44 pruned nodes, max_depth=10
# [71]#011train-error:0.087667#011validation-error:0.148
# [16:45:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 52 pruned nodes, max_depth=10
# [72]#011train-error:0.0876#011validation-error:0.1474
# [16:45:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 52 pruned nodes, max_depth=10
# [73]#011train-error:0.087467#011validation-error:0.1473
# [16:45:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 24 pruned nodes, max_depth=10
# [74]#011train-error:0.087133#011validation-error:0.1474
# [16:45:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 28 pruned nodes, max_depth=10
# [75]#011train-error:0.087533#011validation-error:0.1471
# [16:45:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 28 pruned nodes, max_depth=10
# [76]#011train-error:0.086#011validation-error:0.146
# [16:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 22 pruned nodes, max_depth=10
# [77]#011train-error:0.085533#011validation-error:0.1458
# [16:45:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 46 pruned nodes, max_depth=10
# [78]#011train-error:0.086133#011validation-error:0.1455
# [16:45:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 22 pruned nodes, max_depth=10
# [79]#011train-error:0.085133#011validation-error:0.145
# [16:45:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 36 pruned nodes, max_depth=10
# [80]#011train-error:0.084867#011validation-error:0.1447
# [16:45:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 82 pruned nodes, max_depth=10
# [81]#011train-error:0.083333#011validation-error:0.1451
# [16:46:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 62 pruned nodes, max_depth=10
# [82]#011train-error:0.082#011validation-error:0.1447
# [16:46:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 56 pruned nodes, max_depth=10
# [83]#011train-error:0.0814#011validation-error:0.145
# [16:46:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 52 pruned nodes, max_depth=10
# [84]#011train-error:0.081#011validation-error:0.1436
# [16:46:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 24 pruned nodes, max_depth=10
# [85]#011train-error:0.080733#011validation-error:0.143
# [16:46:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 34 pruned nodes, max_depth=10
# [86]#011train-error:0.0806#011validation-error:0.1431
# [16:46:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 66 pruned nodes, max_depth=10
# [87]#011train-error:0.079933#011validation-error:0.143
# [16:46:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 28 pruned nodes, max_depth=10
# [88]#011train-error:0.079533#011validation-error:0.1433
# [16:46:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 44 pruned nodes, max_depth=10
# [89]#011train-error:0.0792#011validation-error:0.1436
# [16:46:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 66 pruned nodes, max_depth=10
# [90]#011train-error:0.0794#011validation-error:0.1425
# [16:46:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=10
# [91]#011train-error:0.079067#011validation-error:0.1427
# [16:46:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 32 pruned nodes, max_depth=4
# [92]#011train-error:0.079067#011validation-error:0.1422
# [16:46:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 28 pruned nodes, max_depth=10
# [93]#011train-error:0.078867#011validation-error:0.1421
# [16:46:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 30 pruned nodes, max_depth=10
# [94]#011train-error:0.078867#011validation-error:0.1424
# [16:46:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 48 pruned nodes, max_depth=10
# [95]#011train-error:0.078333#011validation-error:0.1414
# [16:46:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 54 pruned nodes, max_depth=10
# [96]#011train-error:0.077133#011validation-error:0.141
# [16:46:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 50 pruned nodes, max_depth=10
# [97]#011train-error:0.076933#011validation-error:0.1402
# [16:46:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 34 pruned nodes, max_depth=10
# [98]#011train-error:0.077#011validation-error:0.1392
# [16:46:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 62 pruned nodes, max_depth=9
# [99]#011train-error:0.076867#011validation-error:0.1396
# [16:46:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 40 pruned nodes, max_depth=8
# [100]#011train-error:0.076333#011validation-error:0.14
# [16:46:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 40 pruned nodes, max_depth=7
# [101]#011train-error:0.076467#011validation-error:0.1398
# [16:46:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 38 pruned nodes, max_depth=9
# [102]#011train-error:0.0758#011validation-error:0.139
# [16:46:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 18 pruned nodes, max_depth=10
# [103]#011train-error:0.0754#011validation-error:0.1382
# [16:46:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 54 pruned nodes, max_depth=5
# [104]#011train-error:0.075733#011validation-error:0.1387
# [16:46:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 46 pruned nodes, max_depth=10
# [105]#011train-error:0.0748#011validation-error:0.139
# [16:47:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 38 pruned nodes, max_depth=9
# [106]#011train-error:0.074733#011validation-error:0.1384
# [16:47:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 52 pruned nodes, max_depth=8
# [107]#011train-error:0.074267#011validation-error:0.1384
# [16:47:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=9
# [108]#011train-error:0.073867#011validation-error:0.1381
# [16:47:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 36 pruned nodes, max_depth=9
# [109]#011train-error:0.073333#011validation-error:0.1391
# [16:47:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 20 pruned nodes, max_depth=9
# [110]#011train-error:0.072733#011validation-error:0.1381
# [16:47:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 54 pruned nodes, max_depth=10
# [111]#011train-error:0.072667#011validation-error:0.1368
# [16:47:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 88 pruned nodes, max_depth=8
# [112]#011train-error:0.072067#011validation-error:0.1363
# [16:47:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=10
# [113]#011train-error:0.071667#011validation-error:0.136
# [16:47:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=10
# [114]#011train-error:0.0716#011validation-error:0.1365
# [16:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 60 pruned nodes, max_depth=2
# [115]#011train-error:0.071467#011validation-error:0.1365
# [16:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 52 pruned nodes, max_depth=9
# [116]#011train-error:0.070933#011validation-error:0.1354
# [16:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 56 pruned nodes, max_depth=0
# [117]#011train-error:0.0712#011validation-error:0.1356
# [16:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 26 pruned nodes, max_depth=1
# [118]#011train-error:0.071133#011validation-error:0.1357
# [16:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 34 pruned nodes, max_depth=0
# [119]#011train-error:0.071067#011validation-error:0.1359
# [16:47:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 58 pruned nodes, max_depth=9
# [120]#011train-error:0.070267#011validation-error:0.1354
# [16:47:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 36 pruned nodes, max_depth=8
# [121]#011train-error:0.069733#011validation-error:0.1352
# [16:47:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 42 pruned nodes, max_depth=9
# [122]#011train-error:0.069933#011validation-error:0.1347
# [16:47:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 50 pruned nodes, max_depth=6
# [123]#011train-error:0.070067#011validation-error:0.1347
# [16:47:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 28 pruned nodes, max_depth=9
# [124]#011train-error:0.069733#011validation-error:0.1349
# [16:47:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 94 pruned nodes, max_depth=10
# [125]#011train-error:0.069533#011validation-error:0.1335
# [16:47:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 42 pruned nodes, max_depth=0
# [126]#011train-error:0.069533#011validation-error:0.1335
# [16:47:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 64 pruned nodes, max_depth=10
# [127]#011train-error:0.068733#011validation-error:0.1345
# [16:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 86 pruned nodes, max_depth=10
# [128]#011train-error:0.0688#011validation-error:0.1354
# [16:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 40 pruned nodes, max_depth=0
# [129]#011train-error:0.068667#011validation-error:0.1354
# [16:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 84 pruned nodes, max_depth=1
# [130]#011train-error:0.068867#011validation-error:0.1353
# [16:48:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 40 pruned nodes, max_depth=9
# [131]#011train-error:0.067733#011validation-error:0.1348
# [16:48:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 30 pruned nodes, max_depth=1
# [132]#011train-error:0.0678#011validation-error:0.1348
# [16:48:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 58 pruned nodes, max_depth=9
# [133]#011train-error:0.0688#011validation-error:0.135
# [16:48:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 68 pruned nodes, max_depth=6
# [134]#011train-error:0.068467#011validation-error:0.1348
# [16:48:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 28 pruned nodes, max_depth=10
# [135]#011train-error:0.068467#011validation-error:0.1351
# Stopping. Best iteration:
# [125]#011train-error:0.069533#011validation-error:0.1335
#
# Training seconds: 414
# Billable seconds: 414

# %% [markdown]
# Now that we have an estimator object attached to the correct training job, we can proceed as we normally would and create a transformer object.

# %%
# TODO: Create a transformer object from the attached estimator. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.

xgb_transformer = xgb_attached.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# ......................Arguments: serve
# [2020-05-02 18:30:05 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-05-02 18:30:05 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-05-02 18:30:05 +0000] [1] [INFO] Using worker: gevent
# [2020-05-02 18:30:05 +0000] [39] [INFO] Booting worker with pid: 39
# [2020-05-02 18:30:05 +0000] [40] [INFO] Booting worker with pid: 40
# [2020-05-02 18:30:05 +0000] [41] [INFO] Booting worker with pid: 41
# [2020-05-02:18:30:05:INFO] Model loaded successfully for worker : 39
# [2020-05-02 18:30:05 +0000] [42] [INFO] Booting worker with pid: 42
# [2020-05-02:18:30:05:INFO] Model loaded successfully for worker : 40
# [2020-05-02:18:30:05:INFO] Model loaded successfully for worker : 41
# [2020-05-02:18:30:05:INFO] Model loaded successfully for worker : 42
# 2020-05-02T18:30:38.860:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2020-05-02:18:30:41:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:41:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:41:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:41:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:41:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:41:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:41:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:41:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:42:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:42:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:42:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:42:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:42:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:42:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:42:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:42:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:44:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:44:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:44:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:44:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:44:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:44:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:44:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:44:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:44:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:44:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:44:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:44:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:44:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:44:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:44:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:44:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:49:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:49:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:49:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:49:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:49:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:49:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:49:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:49:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:49:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:49:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:49:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:49:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:49:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:49:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:49:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:49:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:51:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:51:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:51:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:51:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:51:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:51:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:51:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:51:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:51:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:51:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:51:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:51:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:52:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:52:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:52:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:52:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:54:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:54:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:54:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:54:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:54:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:54:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:54:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:54:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:54:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:54:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:54:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:54:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:54:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:54:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:54:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:54:INFO] Determined delimiter of CSV input is ','
#
# [2020-05-02:18:30:56:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:56:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:56:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:56:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:57:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:57:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:57:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:57:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:58:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:58:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:58:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:58:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:59:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:59:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:59:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:59:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:58:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:58:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:58:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:58:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:59:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:59:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:30:59:INFO] Sniff delimiter as ','
# [2020-05-02:18:30:59:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:01:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:01:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:01:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:01:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:01:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:01:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:01:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:01:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:01:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:01:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:01:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:01:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:01:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:01:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:01:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:01:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:03:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:03:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:03:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:03:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:03:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:03:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:04:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:04:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:04:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:04:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:03:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:03:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:04:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:04:INFO] Determined delimiter of CSV input is ','
# [2020-05-02:18:31:04:INFO] Sniff delimiter as ','
# [2020-05-02:18:31:04:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-eu-west-2-463062221782/xgboost-200502-1618-011-8f4868a2-2020-05-02-18-26-37-171/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.86312

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
